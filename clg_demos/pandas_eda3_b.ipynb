# %%
# Checking duplicates
#df.duplicated()
# df[df.duplicated()]
#  df.drop_duplicates()

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.loc[len(df)]=[891,0,3,"Dooley, Mr. Patrick","male",32.0,	0,0,370376,7.75,"NaN",'Q']
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 888    False
# 889    False
# 890    False
# 891    False
# 892     True
# Length: 893, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 892          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 892      0  370376  7.75   NaN        Q

# %%
#df.tail()
df.drop_duplicates(inplace=True)
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
# 891          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
# 891    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.drop_duplicates(inplace=True)

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
# 891          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q
# 891    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Correlation & Covariance
#df1.corr()
# df.cov()

# %%
df1=df[['Age','Fare','SibSp','Parch']]
df1.head()
# Out:
#     Age     Fare  SibSp  Parch
# 0  22.0   7.2500      1      0
# 1  38.0  71.2833      1      0
# 2  26.0   7.9250      0      0
# 3  35.0  53.1000      1      0
# 4  35.0   8.0500      0      0

# %%
#df1.corr()
df1.cov()
# Out:
#               Age         Fare     SibSp     Parch
# Age    210.730984    73.658892 -4.159152 -2.342296
# Fare    73.658892  2467.335725  8.753253  8.661792
# SibSp   -4.159152     8.753253  1.214985  0.368548
# Parch   -2.342296     8.661792  0.368548  0.649162

# %%
#Data Visualization (Quick Plots)
df2=df['Age']
#df2.hist(figsize=(10, 5)) 
#df1.hist(figsize=(10, 5))    #: Histogram for numerical columns
#df.boxplot(figsize=(10, 5))  #Box plot for outlier detection
#df["Age"].plot(kind="hist") #: Histogram for a single column
#df["Age"].plot(kind="box")#: Box plot for asingle column
df.plot(kind="scatter", x="Age", y="Fare")#: Scatter plot
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
# renaming & adding new coulmn

# %%
df.rename(columns={"PassengerId":"Pid"}, inplace=True)
df.head()
# Out:
#    Pid  Survived  Pclass                                               Name  \
# 0    1         0       3                            Braund, Mr. Owen Harris
# 1    2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    3         1       3                             Heikkinen, Miss. Laina
# 3    4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    5         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
